# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

names = ['mpg', 'cylinders','displacement', 'horsepower', 
         'weight', 'acceleration', 'model year', 'origin', 'car name']
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/'+
                 'auto-mpg/auto-mpg.data',
                 header=None,delim_whitespace=True,names=names,na_values='?')

df1 = df[['horsepower','mpg']]
df2 = df1.dropna()

# %%
x = df2['horsepower']
y= df2['mpg']
plt.plot(x,y,'o')
plt.xlabel("Horsepower")
plt.ylabel("mpg")
plt.grid(True)

# %%
xm = np.mean(x)
ym = np.mean(y)
sxx = np.mean((x-xm)**2)
syy = np.mean((y-ym)**2)
sxy = np.mean((y-ym)*(x-xm))

w1 = sxy/sxx
w0 = ym-w1*xm

print(w1,w0)
# Out:
# -0.1578447333536532 39.935861021170425

# %%
x_model = np.array([25,250])
y_model = w0 + w1*x_model
plt.plot(x,y,'o')
plt.plot(x_model,y_model,'-',linewidth='2')
plt.grid(True)

# %% [markdown]
# ### ASSIGNMENT_2 Q3

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('findata.csv', header = None)
df.head()
# Out:
#       0                            1                     2  \
# 0  Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1  2019                      Level 1                 99999
# 2  2019                      Level 1                 99999
# 3  2019                      Level 1                 99999
# 4  2019                      Level 1                 99999
#
#                       3                   4              5  \
# 0  Industry_name_NZSIOC               Units  Variable_code
# 1        All industries  Dollars (millions)            H01
# 2        All industries  Dollars (millions)            H04
# 3        All industries  Dollars (millions)            H05
# 4        All industries  Dollars (millions)            H07
#
#                                                  6                      7  \
# 0                                    Variable_name      Variable_category
# 1                                     Total income  Financial performance
# ...

# %%
df = pd.concat([pd.Series(1, index=df.index, name='00'), df], axis=1)
df.head()
# Out:
#    00     0                            1                     2  \
# 0   1  Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1   1  2019                      Level 1                 99999
# 2   1  2019                      Level 1                 99999
# 3   1  2019                      Level 1                 99999
# 4   1  2019                      Level 1                 99999
#
#                       3                   4              5  \
# 0  Industry_name_NZSIOC               Units  Variable_code
# 1        All industries  Dollars (millions)            H01
# 2        All industries  Dollars (millions)            H04
# 3        All industries  Dollars (millions)            H05
# 4        All industries  Dollars (millions)            H07
#
#                                                  6                      7  \
# 0                                    Variable_name      Variable_category
# 1                                     Total income  Financial performance
# ...

# %%
from sklearn import datasets, linear_model

# Load the diabetes dataset
diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

# %%
def hypothesis(theta, X):
    return theta*X

# %%
def computeCost(X, y, theta):
    y1 = hypothesis(theta, X)
    print(y1)
    y2=np.sum(y1, axis=1)
    print(y2)
    return sum(np.sqrt((y2-y)**2))/(2*47)

# %%
def gradient_descent(init, steps, grad):
    xs = [init]
    for step in steps:
        xs.append(xs[-1] - step * grad(xs[-1])) 
    return xs

# %%
# J, j, theta = gradient_descent(X, 0.05, 10000)
